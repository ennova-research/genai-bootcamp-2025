# %% [markdown]
# # 💻 Generative AI Bootcamp – Session 2
# ## Icebreaker & Setup Lab
#
# This notebook helps verify your development environment and API connectivity.

# %% [markdown]
# ### 1. Check Python Version

# %%
import sys
print('Python version:', sys.version)

# %% [markdown]
# ### 2. Verify Key Libraries

# %%
import requests
import google.genai, openai
print('requests version:', requests.__version__)
print('google genai version:', google.genai.__version__)
print('openai version:', openai.__version__)

# %% [markdown]
# ### 3. Test OpenAI API Connection

# %%
import dotenv
dotenv.load_dotenv()

from openai import OpenAI
client = OpenAI()
models = client.models.list()
print('✅ API connection successful!')
print('Available models:', [m.id for m in models.data[:5]])

# %% [markdown]
# ### 4. Quick Test Prompt

# %%
prompt = 'Write one sentence about why learning AI is exciting.'
response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{'role': 'user', 'content': prompt}]
)
print(response.choices[0].message.content)

# %% [markdown]
# ### 5. All Set!
# If all checks ran successfully, you’re ready to write analogous calls using the `google.genai` SDK.
